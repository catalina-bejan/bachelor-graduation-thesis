# %%
# !nvidia-smi
# Out:
# Sat Feb 13 15:24:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import pandas as pd
import numpy as np
import keras
import glob
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
from mlxtend.preprocessing import minmax_scaling
from sklearn.metrics import roc_curve, auc

from keras.utils.np_utils import to_categorical
from keras.models import Sequential, Model, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Input, BatchNormalization, Multiply, Activation
from keras.optimizers import RMSprop, SGD
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras import backend as K
import tensorflow_hub as hub

import os

# %%
# find file paths
food = ['apple_pie','baby_back_ribs', 'baklava'] 
f_train_path = '/content/drive/MyDrive/Colab Projects/food_3classes100Photos/train/'
f_test_path = '/content/drive/MyDrive/Colab Projects/food_3classes100Photos/test/'
f_apple = glob.glob(f_train_path + food[0]+'/*')
f_baby = glob.glob(f_train_path + food[1]+'/*')
f_baklava = glob.glob(f_train_path + food[2]+'/*')
f_apple_test = glob.glob(f_test_path + food[0]+'/*')
f_baby_test = glob.glob(f_test_path + food[1]+'/*')
f_baklava_test = glob.glob(f_test_path + food[2]+'/*')
# total 1000 files for each category
print('Number of images per class:\n\t\ttrain\ttest \nApple_pie:\t{}\t{}\nBaby_pork_ribs:\t{}\t{}\nBaklava:\t{}\t{}'
      .format(len(f_apple),len(f_apple_test),len(f_baby),len(f_baby_test),len(f_baklava),len(f_baklava_test)))
# Out:
# Number of images per class:
# 		train	test
# Apple_pie:	150	30
# Baby_pork_ribs:	150	30
# Baklava:	150	30

# %%
# preview some images of each class
n = 7
from glob import glob
classes_number = len(glob(f_train_path + '/*'))
fig, axes = plt.subplots(classes_number,n,figsize=(20,10))

for i in range(n):
    axes[0, i].imshow(plt.imread(f_apple[i]))
    axes[0, i].set_title('apple pie')
    axes[1, i].imshow(plt.imread(f_baby[i]))
    axes[1, i].set_title('baby pork ribs')
    axes[2, i].imshow(plt.imread(f_baklava[i]))
    axes[2, i].set_title('baklava')

# %% [markdown]
# The images are of different sizes and aspect ratio, with at least one side of 512 pixels.

# %%
for i in range(len(f_apple)):
    h1,w1,c1 = plt.imread(f_apple[i]).shape
    h2,w2,c2 = plt.imread(f_baby[i]).shape
    h3,w3,c3 = plt.imread(f_baklava[i]).shape
    plt.scatter(h1,w1,c='r',marker='x',alpha=0.5)
    plt.scatter(h2,w2,c='c',marker='o',alpha=0.5)
    plt.scatter(h3,w3,c='b',marker='v',alpha=0.5)
plt.title('Image Size')
plt.legend(('apples','babies','baklavas'))

# %% [markdown]
# **Data Augmentation**

# %% [markdown]
# In order to avoid overfitting problem and to expand the dataset. Image data generator from Keras is used for image tranformation.

# %%
train_datagen = ImageDataGenerator(featurewise_center=False,
                 samplewise_center=False,
                 featurewise_std_normalization=False,
                 samplewise_std_normalization=False,
                 zca_whitening=False,
                 rotation_range=5,
                 width_shift_range=0.05,
                 height_shift_range=0.05,
                 shear_range=0.2,
                 zoom_range=0.2,
                 channel_shift_range=0.,
                 fill_mode='nearest',
                 cval=0.,
                 horizontal_flip=True,
                 vertical_flip=False,
                 rescale=1/255) #normalize image, add zoom range of 0.2x and horizontal flip
train_generator = train_datagen.flow_from_directory( #images are loaded progressively in alphabetical order and assigned an integer for each class 
        f_train_path,
        target_size=(224,224),
        batch_size=32)
test_datagen = ImageDataGenerator(rescale=1/255) # just normalize for testing set
test_generator = test_datagen.flow_from_directory(
        f_test_path,
        target_size=(224,224),
        batch_size=32)
# Out:
# Found 450 images belonging to 3 classes.
# Found 90 images belonging to 3 classes.

# %%
# preview images from train generator
r = 4; c = 7
n=0
classtolabel = {'0':'apple_pie','1':'baby_pork_ribs','2':'baklava'} #alphabetical order, each class assigned an integer because of flow_from_directory() function
for x in train_generator:
    fig, axes = plt.subplots(r,c,figsize=(20,12))
    for i in range(r):
        for j in range(c):
            axes[i,j].imshow(x[0][n])
            label = np.argmax(x[1],axis=1)[n].astype('str')
            axes[i,j].set_title(classtolabel[label])
            n+=1    
    break

# %% [markdown]
# Modelling

# %% [markdown]
# Transfer Learning with TensorFlow Hub

# %%
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(URL,
                                   input_shape=(224, 224,3))

# %% [markdown]
# Freeze the variables in the feature extractor layer, so that the training only modifies the final classifier layer.

# %%
feature_extractor.trainable = False

# %%
model = Sequential([
  feature_extractor,
  Dense(3, activation = "softmax",kernel_initializer='he_normal',kernel_regularizer=l2())])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_2 (KerasLayer)   (None, 1280)              2257984
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
#callbacks
checkpointer = ModelCheckpoint(filepath='model.hdf5', verbose=1, save_best_only=True, save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=20, mode='auto')
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, mode='auto')

model.compile(optimizer = 'Adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_2 (KerasLayer)   (None, 1280)              2257984
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
train_photos = 450
test_photos = 90
batch_size = 32
history = model.fit_generator(train_generator,steps_per_epoch=train_photos/batch_size,
                              validation_data=test_generator,validation_steps=test_photos/batch_size, 
                              epochs=20, callbacks=[checkpointer, reduceLR, earlystopping])
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 14/14 [==============================] - 7s 516ms/step - loss: 0.4330 - accuracy: 0.8689 - val_loss: 0.5748 - val_accuracy: 0.7889
#
# Epoch 00001: val_loss improved from 0.59192 to 0.57480, saving model to model.hdf5
# Epoch 2/20
# 14/14 [==============================] - 7s 504ms/step - loss: 0.4141 - accuracy: 0.8733 - val_loss: 0.5539 - val_accuracy: 0.8222
#
# Epoch 00002: val_loss improved from 0.57480 to 0.55394, saving model to model.hdf5
# Epoch 3/20
# 14/14 [==============================] - 7s 501ms/step - loss: 0.3857 - accuracy: 0.8911 - val_loss: 0.5318 - val_accuracy: 0.8333
#
# Epoch 00003: val_loss improved from 0.55394 to 0.53179, saving model to model.hdf5
# Epoch 4/20
# 14/14 [==============================] - 7s 503ms/step - loss: 0.3796 - accuracy: 0.9000 - val_loss: 0.5491 - val_accuracy: 0.8222
#
# Epoch 00004: val_loss did not improve from 0.53179
# Epoch 5/20
# 14/14 [==============================] - 7s 509ms/step - loss: 0.3619 - accuracy: 0.9089 - val_loss: 0.5184 - val_accuracy: 0.8000
#
# Epoch 00005: val_loss improved from 0.53179 to 0.51838, saving model to model.hdf5
# Epoch 6/20
# 14/14 [==============================] - 7s 503ms/step - loss: 0.3372 - accuracy: 0.9156 - val_loss: 0.5118 - val_accuracy: 0.8111
#
# Epoch 00006: val_loss improved from 0.51838 to 0.51182, saving model to model.hdf5
# Epoch 7/20
# 14/14 [==============================] - 7s 538ms/step - loss: 0.3325 - accuracy: 0.9089 - val_loss: 0.5125 - val_accuracy: 0.8000
#
# Epoch 00007: val_loss did not improve from 0.51182
# Epoch 8/20
# 14/14 [==============================] - 7s 503ms/step - loss: 0.3076 - accuracy: 0.9244 - val_loss: 0.5088 - val_accuracy: 0.8111
#
# Epoch 00008: val_loss improved from 0.51182 to 0.50875, saving model to model.hdf5
# Epoch 9/20
# 14/14 [==============================] - 7s 496ms/step - loss: 0.3072 - accuracy: 0.9178 - val_loss: 0.5152 - val_accuracy: 0.8333
#
# Epoch 00009: val_loss did not improve from 0.50875
# Epoch 10/20
# 14/14 [==============================] - 7s 510ms/step - loss: 0.2902 - accuracy: 0.9222 - val_loss: 0.5244 - val_accuracy: 0.8222
#
# Epoch 00010: val_loss did not improve from 0.50875
# Epoch 11/20
# 14/14 [==============================] - 7s 508ms/step - loss: 0.2954 - accuracy: 0.9311 - val_loss: 0.5120 - val_accuracy: 0.8000
#
# Epoch 00011: val_loss did not improve from 0.50875
# Epoch 12/20
# 14/14 [==============================] - 7s 503ms/step - loss: 0.3010 - accuracy: 0.9267 - val_loss: 0.5113 - val_accuracy: 0.8111
#
# Epoch 00012: val_loss did not improve from 0.50875
# Epoch 13/20
# 14/14 [==============================] - 7s 504ms/step - loss: 0.2545 - accuracy: 0.9556 - val_loss: 0.5197 - val_accuracy: 0.7889
#
# Epoch 00013: val_loss did not improve from 0.50875
# Epoch 14/20
# 14/14 [==============================] - 7s 502ms/step - loss: 0.2609 - accuracy: 0.9622 - val_loss: 0.5149 - val_accuracy: 0.7889
#
# Epoch 00014: val_loss did not improve from 0.50875
# Epoch 15/20
# 14/14 [==============================] - 7s 513ms/step - loss: 0.2722 - accuracy: 0.9533 - val_loss: 0.5125 - val_accuracy: 0.8000
#
# Epoch 00015: val_loss did not improve from 0.50875
# Epoch 16/20
# 14/14 [==============================] - 7s 503ms/step - loss: 0.2425 - accuracy: 0.9644 - val_loss: 0.5026 - val_accuracy: 0.7889
#
# Epoch 00016: val_loss improved from 0.50875 to 0.50259, saving model to model.hdf5
# Epoch 17/20
# 14/14 [==============================] - 7s 498ms/step - loss: 0.2555 - accuracy: 0.9467 - val_loss: 0.4936 - val_accuracy: 0.8222
#
# Epoch 00017: val_loss improved from 0.50259 to 0.49356, saving model to model.hdf5
# Epoch 18/20
# 14/14 [==============================] - 7s 501ms/step - loss: 0.2404 - accuracy: 0.9511 - val_loss: 0.4912 - val_accuracy: 0.8111
#
# Epoch 00018: val_loss improved from 0.49356 to 0.49120, saving model to model.hdf5
# Epoch 19/20
# 14/14 [==============================] - 7s 500ms/step - loss: 0.2429 - accuracy: 0.9622 - val_loss: 0.5050 - val_accuracy: 0.7889
#
# Epoch 00019: val_loss did not improve from 0.49120
# Epoch 20/20
# 14/14 [==============================] - 7s 500ms/step - loss: 0.2372 - accuracy: 0.9556 - val_loss: 0.4960 - val_accuracy: 0.8333
#
# Epoch 00020: val_loss did not improve from 0.49120

# %% [markdown]
# trained for 25 epochs total

# %%
def plot_hist(history):
    f,ax = plt.subplots(2,1,figsize=(15,10))
    ax[0].plot(history.history['accuracy'],c='C2')
    ax[0].plot(history.history['val_accuracy'],c='C3')
    ax[0].set_title('Model accuracy')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='upper left')
    
    # summarize history for loss
    ax[1].plot(history.history['loss'],c='C0')
    ax[1].plot(history.history['val_loss'],c='C1')
    ax[1].set_title('Model loss')
    ax[1].set_ylabel('Loss')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='upper left')
    
plot_hist(history)

# %% [markdown]
# **Evaluate results**

# %%
# create another generator for all test images in a single batch (90 photos total in test)
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = test_datagen.flow_from_directory(
        f_test_path,
        target_size=(224,224),
        batch_size=90)
# Out:
# Found 90 images belonging to 3 classes.

# %% [markdown]
# **Prediction**

# %%
x_test, y_test = val_generator.next()
y_pred_conf = model.predict(x_test) #return probabilities of each class
y_pred = np.argmax(y_pred_conf,axis=1)
y_label = np.argmax(y_test,axis=1)

print('Accuracy score: {:.1f}%'.format(accuracy_score(y_pred,y_label)*100))
# Out:
# Accuracy score: 83.3%

# %% [markdown]
# Randomly check 10 predictions

# %%
#ind = np.random.randint(1,len(x_test),10)
f, ax=plt.subplots(2,5,figsize=(20,10))
#for i,j in enumerate(ind):
#for i,j in enumerate(ind):
for k in range(2):
  for l in range(5):
      j=np.random.randint(1,len(x_test))
      ax[k,l].imshow(x_test[j])
      ax[k,l].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                            (classtolabel[str(y_pred[j])],np.max(y_pred_conf[j]),
                            classtolabel[str(y_label[j])],y_pred_conf[j][(y_label[j])],fontweight="bold", size=20))

# %% [markdown]
# **Confusion Matrix**

# %%
def plot_confusion_matrix(cm):    
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix',fontsize=15)
    plt.colorbar()
    classes = ['apple_pie','baby_pork_ribs','baklava']
    plt.xticks([0,1,2], classes, fontsize=10)
    plt.yticks([0,1,2], classes, fontsize=10,rotation=90,verticalalignment="center")
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center", color="white" if cm[i, j] > np.max(cm)/2. else "black")
    plt.xlabel('Predicted label',fontsize=15)
    plt.ylabel('True label',fontsize=15)
    
plot_confusion_matrix(confusion_matrix(y_label,y_pred))

# %% [markdown]
# Inspect the predictions with wrong labels

# %%
# find the wrong-est label (largest confidence wrong label)
def show_wrongest_label(x_test,y_test,y_pred_conf):
    y_pred = np.argmax(y_pred_conf,axis=1) # convert predictions to labels
    y_label = np.argmax(y_test,axis=1) # convert answer to labels

    errors = (y_pred - y_label != 0) # find booleans of wrong predictions
    y_pred_errors = y_pred_conf[errors] #the probabilities of the wrong Y_pred [0.5,0.2,0.3]

    y_pred_classes_errors = y_pred[errors] # the wrong pred label [2]
    y_pred_errors_prob = np.max(y_pred_errors,axis = 1) # Probabilities of the wrong predicted numbers [0.5]

    y_true_classes_errors = y_label[errors] # the true label [0]
    y_true_errors_prob = np.diagonal(np.take(y_pred_errors, y_true_classes_errors, axis=1)) # Predicted prob of the true values in the error set[0.2]

    img_errors = x_test[errors] # image of each errors

    # Difference between the probability of the predicted label and the true label
    delta_pred_true_errors = y_pred_errors_prob - y_true_errors_prob
    # Get index of delta prob errors in ascending order
    sorted_delta_errors = np.argsort(delta_pred_true_errors)
    # The index of top 15 errors 
    most_important_errors = sorted_delta_errors[-15:]
    
    
    def display_errors(errors_index,img_errors,pred_errors, obs_errors):
        n = 0
        nrows = 3
        ncols = 5
        fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
        fig.set_figheight(20)
        fig.set_figwidth(30)
        for row in range(nrows):
            for col in range(ncols):
                error = errors_index[n]
                ax[row,col].imshow((img_errors[error]))
                ax[row,col].set_title("Pred :{}({:.2f})\nTrue :{}({:.2f})".format
                                      (classtolabel[pred_errors[error].astype('str')],y_pred_errors_prob[error],
                                       classtolabel[obs_errors[error].astype('str')],y_true_errors_prob[error]),
                                      fontweight="bold", size=20)
                n += 1
    
    display_errors(most_important_errors, img_errors, y_pred_classes_errors, y_true_classes_errors)

# %%
show_wrongest_label(x_test,y_test,y_pred_conf)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Same model as keras .h5 model

# %% [markdown]
# I save the model as an HDF5 file, which is the format used by Keras. The HDF5 file will have the extension '.h5'

# %%
export_path_keras = "/content/drive/MyDrive/Colab Projects/mobilenet_model.h5"
print(export_path_keras)

model.save(export_path_keras)
# Out:
# /content/drive/MyDrive/Colab Projects/mobilenet_model.h5

# %% [markdown]
# You can later recreate the same model from this file, even if you no longer have access to the code that created the model.
#
# This file includes:
#
# The model's architecture
# The model's weight values (which were learned during training)
# The model's training config (what you passed to compile), if any
# The optimizer and its state, if any (this enables you to restart training where you left off)
# https://colab.research.google.com/github/tensorflow/examples/blob/master/courses/udacity_intro_to_tensorflow_for_deep_learning/l07c01_saving_and_loading_models.ipynb#scrollTo=JgqmH1WVUKli

# %% [markdown]
# Load model as keras model

# %% [markdown]
# We will now load the model we just saved into a new model called reloaded. We will need to provide the file path and the custom_objects parameter. This parameter tells keras how to load the hub.KerasLayer from the feature_extractor we used for transfer learning.

# %%
export_path_keras = "/content/drive/MyDrive/Colab Projects/mobilenet_model.h5"
reloaded = load_model( #or just load_model because the package is imported already
  export_path_keras, 
  # `custom_objects` tells keras how to load a `hub.KerasLayer`
  custom_objects={'KerasLayer': hub.KerasLayer})

reloaded.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_2 (KerasLayer)   (None, 1280)              2257984
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# Predict single image

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img

# %%
#make a threshold such that, only if the model is at least 50% sure that the object is food then food exists in the picture
img=load_img('/content/drive/MyDrive/Colab Projects/food_3classes100Photos/test/apple_pie/bike.jpg',target_size=(224,224))
plt.imshow(img)
img = np.array(img).astype('float32')/255
#print(img.shape)
img = np.expand_dims(img, axis=0)
#img.shape
reloaded.predict(img)
# Out:
# array([[0.3102876 , 0.4010322 , 0.28868023]], dtype=float32)

# %%
classtolabel = {'0':'apple_pie','1':'baby_pork_ribs','2':'baklava'}
result = reloaded.predict(img)
maximum = np.max(result)
y_pred = np.argmax(result,axis=1)
if maximum >= 0.5: #apply threshold of 50% 
  print(classtolabel[str(y_pred[0])])
else:
  print('the model is not sure if there is even food in the picture')
# Out:
# the model is not sure if there is even food in the picture
